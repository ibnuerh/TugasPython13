# %% [markdown]
# <a href="https://colab.research.google.com/github/ibnuerh/TugasPython13/blob/main/IbnuerhPyth13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def Pathloss(frek, tipe_area, tinggi_pemancar, tinggi_penerima,jarak):
  if frek in range(150,1501):
    c1=69.55
    c2=26.16
  elif frek in range(1501,2001):
    c1=46.3
    c2=33.9

  if tipe_area == 'Urban':
    cm=0
  elif tipe_area == 'Suburban':
    cm= -2*((np.log10((frek/28)**2))-5.4)
  elif tipe_area == 'Open':
    cm= -4.78*(np.log10(frek))+18.33*(np.log10(frek))-40.94
  else :
    cm='Wrong Tipe'

  ahr = (1.1*np.log10(frek)-0.7)*tinggi_penerima-(1.56*np.log10(frek)-1.8)
  Lp = c1 + (c2*np.log10(frek))-(13.83*np.log(tinggi_pemancar))-ahr+((44.9-6.55*np.log10(tinggi_pemancar))*np.log10(jarak))-cm

  return Lp

# %%
f=1800
area1='Urban'
area2='Suburban'
area3= 'Open'
trans = 80
rece = 1.5
jmin = 200
jmax = 700
user = 200
j = np.random.randint(jmin,jmax,user)

# %%
Graph1=Pathloss(f,area1,trans,rece,j)
Graph2=Pathloss(f,area2,trans,rece,j)
Graph3=Pathloss(f,area3,trans,rece,j)

# %%
plt.figure()
plt.plot(j,Graph1,label="Urban")
plt.plot(j,Graph2,label="Suburban")
plt.plot(j,Graph3,label="Open")
plt.legend()
plt.title("Grafik Frekuensi 1800Mhz")
plt.xlabel("Jarak (m)")
plt.xlabel("Pathloss(dB)")
plt.show()

# %%
j_sort=j[np.argsort(j)]
Urban_sort=Graph1[np.argsort(j)]
Suburban_sort=Graph2[np.argsort(j)]
Open_sort=Graph3[np.argsort(j)]

# %%
plt.figure()
plt.plot(j_sort,Urban_sort,label="Urban")
plt.plot(j_sort,Suburban_sort,label="Suburban")
plt.plot(j_sort,Open_sort,label="Open")
plt.legend()
plt.title("Grafik Frekuensi 1800Mhz")
plt.xlabel("Jarak (m)")
plt.xlabel("Pathloss(dB)")
plt.show()

# %%
f1=700
f2=900
f3=1800
area='Urban'
trans = 80
rece = 1.5
jmin = 200
jmax = 700
user = 200
j = np.random.randint(jmin,jmax,user)

# %%
GraphFrek1=Pathloss(f1,area,trans,rece,j)
GraphFrek2=Pathloss(f2,area,trans,rece,j)
GraphFrek3=Pathloss(f3,area,trans,rece,j)

# %%
plt.figure()
plt.plot(j,GraphFrek1,label="700Mhz")
plt.plot(j,GraphFrek2,label="900Mhz")
plt.plot(j,GraphFrek3,label="1800Mhz")
plt.legend()
plt.title("Grafik Lokasi Urban")
plt.xlabel("Jarak (m)")
plt.xlabel("Pathloss(dB)")
plt.show()

# %%
j_sort=j[np.argsort(j)]
frek1_sort=GraphFrek1[np.argsort(j)]
frek2_sort=GraphFrek2[np.argsort(j)]
frek3_sort=GraphFrek3[np.argsort(j)]

# %%
plt.figure()
plt.plot(j_sort,frek1_sort,label="700Mhz")
plt.plot(j_sort,frek2_sort,label="900Mhz")
plt.plot(j_sort,frek3_sort,label="1800Mhz")
plt.legend()
plt.title("Grafik Lokasi Urban")
plt.xlabel("Jarak (m)")
plt.xlabel("Pathloss(dB)")
plt.show()
